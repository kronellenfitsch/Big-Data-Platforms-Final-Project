# %% [markdown]
# # Big Data Platforms - Final Project
# ### Data Filtering (Spark Script)
# ### By Kyla Ronellenfitsch
# ### March 19, 2021

# %% [markdown]
# ## EDA and Variable Selection

# %%
# Import relevant packages 
import os
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
from itertools import islice
import re

import shutil
# import sh
from pyspark.sql.functions import *
import pyspark.sql.functions as psf
from pyspark.sql.types import *

# %%
# Instatiate storage 
from google.cloud import storage

# %%
# Preview all files 
# !hadoop fs -ls "gs://msca-bdp-tweets/Tweets/" | head -10
# Out:
# Found 30241 items
# -rwx------   3 root root   55220293 2020-10-21 00:01 gs://msca-bdp-tweets/Tweets/tweets201706221015.json
# -rwx------   3 root root   52384528 2020-10-20 22:16 gs://msca-bdp-tweets/Tweets/tweets201706221115.json
# -rwx------   3 root root   56190692 2020-10-20 22:45 gs://msca-bdp-tweets/Tweets/tweets201706221215.json
# -rwx------   3 root root   56992695 2020-10-21 00:00 gs://msca-bdp-tweets/Tweets/tweets201706221315.json
# -rwx------   3 root root   54702790 2020-10-21 00:16 gs://msca-bdp-tweets/Tweets/tweets201706221415.json
# -rwx------   3 root root   66415029 2020-10-21 02:43 gs://msca-bdp-tweets/Tweets/tweets201706221515.json
# -rwx------   3 root root   63298555 2020-10-21 02:13 gs://msca-bdp-tweets/Tweets/tweets201706221615.json
# -rwx------   3 root root   55417269 2020-10-20 22:04 gs://msca-bdp-tweets/Tweets/tweets201706221715.json
# -rwx------   3 root root   54057246 2020-10-21 03:06 gs://msca-bdp-tweets/Tweets/tweets201706221815.json

# %%
# Read in one file to understand structure and conduct EDA
# %time twitter_ex = spark.read.json('gs://msca-bdp-tweets/Tweets/tweets201706221115.json')
twitter_ex.count()
# Out:
# CPU times: user 5.39 ms, sys: 130 µs, total: 5.52 ms
# Wall time: 9.79 s
# 9458

# %%
# print schema. This was essential for variable selection, but not printed here due to length

#twitter_ex.printSchema()

# %%
# selection of words for universities 
words = ["uchicago", 
         "university of chicago", 
         "depaul", 
         "depaul university", 
         "depaulu",
         "northwestern",
         "northwesternu",
         "northwestern university",
         "university of illinois at chicago",
         "uic.edu", 
         " uic ",
         " uic's "
         ]

# %%
# time data filtering 
# %time fltr = twitter_ex.filter(psf.lower(twitter_ex.text).rlike('|'.join(words)))
# Out:
# CPU times: user 5.7 ms, sys: 7.96 ms, total: 13.7 ms
# Wall time: 217 ms

# %%
# signficant reduction in volume 
fltr.count()
# Out:
# 101

# %%
# preview data
fltr.limit(5).toPandas()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Thu Jun 22 15:16:19 +0000 2017               None
# 1         None        None  Thu Jun 22 15:17:15 +0000 2017               None
# 2         None        None  Thu Jun 22 15:17:53 +0000 2017               None
# 3         None        None  Thu Jun 22 15:18:23 +0000 2017            [0, 91]
# 4         None        None  Thu Jun 22 15:18:42 +0000 2017               None
#
#                                             entities  \
# 0  ([], None, [], [(depaulnewsline.com/features/f...
# 1  ([], None, [], [(northwesternmutual.com/news-r...
# 2  ([([66, 79], Northwestern), ([86, 94], B1GCats...
# 3  ([], [(pic.twitter.com/xApl204yoj, https://twi...
# 4                             ([], None, [], [], [])
#
#                                    extended_entities extended_tweet  \
# 0                                               None           None
# 1                                               None           None
# 2                                               None           None
# 3  ([(pic.twitter.com/xApl204yoj, https://twitter...           None
# 4                                               None           None
#
#    favorite_count  favorited filter_level  ... quoted_status_id_str  \
# 0               0      False          low  ...                 None
# 1               0      False          low  ...                 None
# 2               0      False          low  ...                 None
# 3               0      False          low  ...                 None
# 4               0      False          low  ...                 None
#
#    retweet_count retweeted retweeted_status  \
# 0              0     False             None
# 1              0     False             None
# 2              0     False             None
# 3              0     False             None
# 4              0     False             None
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://paper.li" rel="nofollow">Paper...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms truncated  \
# 0  Future now: @DePaulU's innovative strategies d...  1498144579490     False
# 1  Northwestern Mutual Life Insurance and Financi...  1498144635844     False
# 2  Read Daily @NU_Alumni for summary of last 24 h...  1498144673637     False
# 3  When a visitor comes to the Medill campus and ...  1498144703822     False
# 4  I keep getting emails from DePaul and I'm so s...  1498144722730     False
#
#                                                 user withheld_in_countries
# 0  (False, Tue Aug 05 16:38:08 +0000 2014, True, ...                  None
# 1  (False, Sun Mar 10 14:23:19 +0000 2013, True, ...                  None
# 2  (False, Tue Feb 10 18:11:05 +0000 2009, False,...                  None
# 3  (False, Tue May 31 04:08:57 +0000 2011, False,...                  None
# 4  (False, Sun Dec 15 05:31:59 +0000 2013, False,...                  None
#
# [5 rows x 35 columns]

# %%
# filter relevant columns, time
# %time fltr2 = twitter_ex.filter(psf.lower(twitter_ex.text).rlike('|'.join(words))).\
select([col("created_at").alias("tweet_created"),\
        "text",\
        "retweet_count",\
        "favorite_count",\
        "filter_level",\
        "quoted_status_id_str",\
        "user.created_at",\
        "user.default_profile_image",\
        "user.description",\
        "user.favourites_count",\
        "user.followers_count",\
        "user.following",\
        "user.friends_count",\
        "user.id_str",\
        "user.screen_name",\
        "user.statuses_count",\
        "user.location",\
        "user.time_zone",\
        "user.verified"])
# Out:
# CPU times: user 12.5 ms, sys: 10 µs, total: 12.5 ms
# Wall time: 75.8 ms

# %%
# save as pandas df 
df = fltr2.toPandas()

# %%
# preview
df.head()
# Out:
#                     tweet_created  \
# 0  Thu Jun 22 15:16:19 +0000 2017
# 1  Thu Jun 22 15:17:15 +0000 2017
# 2  Thu Jun 22 15:17:53 +0000 2017
# 3  Thu Jun 22 15:18:23 +0000 2017
# 4  Thu Jun 22 15:18:42 +0000 2017
#
#                                                 text  retweet_count  \
# 0  Future now: @DePaulU's innovative strategies d...              0
# 1  Northwestern Mutual Life Insurance and Financi...              0
# 2  Read Daily @NU_Alumni for summary of last 24 h...              0
# 3  When a visitor comes to the Medill campus and ...              0
# 4  I keep getting emails from DePaul and I'm so s...              0
#
#    favorite_count filter_level quoted_status_id_str  \
# 0               0          low                 None
# 1               0          low                 None
# 2               0          low                 None
# 3               0          low                 None
# 4               0          low                 None
#
#                        created_at  default_profile_image  \
# 0  Tue Aug 05 16:38:08 +0000 2014                  False
# 1  Sun Mar 10 14:23:19 +0000 2013                  False
# 2  Tue Feb 10 18:11:05 +0000 2009                  False
# 3  Tue May 31 04:08:57 +0000 2011                  False
# 4  Sun Dec 15 05:31:59 +0000 2013                  False
#
#                                          description  favourites_count  \
# 0  Newsline is a publication for the university c...               490
# 1  Compensation consultant, teacher and student o...                 0
# 2  Promoting #Northwestern University alumni & #B...             17934
# 3  Dillard University Alum | Medill MSJ '17 | sen...             34189
# 4  🇲🇽                                            ...              2446
#
#    followers_count following  friends_count      id_str     screen_name  \
# 0              611      None            281  2709796375  DePaulNewsline
# 1               87      None            153  1257129522      JimSillery
# 2             1373      None           2439    20531237       NU_alumni
# 3             2926      None           1765   308281620     AstasiaWill
# 4              155      None            522  2246686820          cynxcv
#
#    statuses_count          location                   time_zone  verified
# 0            1365           Chicago                        None     False
# 1             506  Eden Prairie, MN                        None     False
# 2           11382       Chicago, IL  Central Time (US & Canada)     False
# 3          115663          out here  Central Time (US & Canada)     False
# 4            2969           Chicago  Eastern Time (US & Canada)     False

# %%
# describe data 
df.describe()
# Out:
#        retweet_count  favorite_count  favourites_count  followers_count  \
# count          101.0           101.0        101.000000       101.000000
# mean             0.0             0.0       3844.841584      5292.079208
# std              0.0             0.0       8264.886249     29349.339669
# min              0.0             0.0          0.000000         3.000000
# 25%              0.0             0.0         54.000000       200.000000
# 50%              0.0             0.0        853.000000       525.000000
# 75%              0.0             0.0       3017.000000      1751.000000
# max              0.0             0.0      46995.000000    287626.000000
#
#        friends_count  statuses_count
# count     101.000000      101.000000
# mean     1079.910891    29709.049505
# std      4242.378871    96250.963816
# min         0.000000        6.000000
# 25%       185.000000      722.000000
# 50%       424.000000     4390.000000
# 75%       849.000000    14371.000000
# max     42693.000000   793808.000000

# %%
# show missing values and data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_created          101 non-null    object
#  1   text                   101 non-null    object
#  2   retweet_count          101 non-null    int64
#  3   favorite_count         101 non-null    int64
#  4   filter_level           101 non-null    object
#  5   quoted_status_id_str   6 non-null      object
#  6   created_at             101 non-null    object
#  7   default_profile_image  101 non-null    bool
#  8   description            90 non-null     object
#  9   favourites_count       101 non-null    int64
#  10  followers_count        101 non-null    int64
#  11  following              0 non-null      object
#  12  friends_count          101 non-null    int64
#  13  id_str                 101 non-null    object
#  14  screen_name            101 non-null    object
#  15  statuses_count         101 non-null    int64
#  16  location               77 non-null     object
#  17  time_zone              64 non-null     object
#  18  verified               101 non-null    bool
# dtypes: bool(2), int64(6), object(11)
# memory usage: 13.7+ KB

# %%
# show location 
pd.DataFrame(np.unique(df[['location']].astype(str), return_counts=True)).T[:20]
# Out:
#                                 0   1
# 0          North America / Canada   1
# 1                      436 oldham   1
# 2    58th St & Ellis Ave, Chicago   1
# 3                             814   1
# 4             Ann Arbor, Michigan   1
# 5                        Asleep\n   1
# 6                   Beckville, TX   1
# 7                   Beckville, Tx   1
# 8                    Beckville,TX   1
# 9       Bergen County, New Jersey   1
# 10  Between Boston and Woods Hole   1
# 11         Carol Stream, Illinois   1
# 12                   Carthage Tx    1
# 13                   Carthage, TX   3
# 14                        Chicago   4
# 15          Chicago and New Delhi   1
# 16      Chicago by way of Vermont   1
# 17                    Chicago, IL  16
# 18              Chicago, Illinois   2
# 19            College Station, TX   1

# %%
# show timezone 
pd.DataFrame(np.unique(df[['time_zone']].astype(str), return_counts=True)).T
# Out:
#                               0   1
# 0                       Arizona   1
# 1                 Asia/Calcutta   1
# 2                        Athens   1
# 3        Atlantic Time (Canada)   1
# 4    Central Time (US & Canada)  26
# 5    Eastern Time (US & Canada)  16
# 6   Mountain Time (US & Canada)   2
# 7    Pacific Time (US & Canada)  14
# 8                         Quito   1
# 9                          Rome   1
# 10                          nan  37

# %%
#aggregate number of tweets based on id
pd.DataFrame(np.unique(df[['id_str']].astype(str), return_counts=True)).T.sort_values(by=1, ascending=False)
# Out:
#              0  1
# 50  3282487556  3
# 76    68506542  3
# 4   1176776017  2
# 22  2430625008  2
# 25   249409119  2
# ..         ... ..
# 31   261714115  1
# 30   261711658  1
# 29   258922521  1
# 28  2535245767  1
# 93    99413928  1
#
# [94 rows x 2 columns]

# %%
pd.set_option('display.max_colwidth', 200)

# %%
# preview northwestern data 
df[df['text'].str.contains("Northwestern", na=False)][:10]
# Out:
#                      tweet_created  \
# 1   Thu Jun 22 15:17:15 +0000 2017
# 2   Thu Jun 22 15:17:53 +0000 2017
# 3   Thu Jun 22 15:18:23 +0000 2017
# 8   Thu Jun 22 15:21:54 +0000 2017
# 9   Thu Jun 22 15:22:01 +0000 2017
# 10  Thu Jun 22 15:22:12 +0000 2017
# 11  Thu Jun 22 15:24:06 +0000 2017
# 12  Thu Jun 22 15:24:35 +0000 2017
# 13  Thu Jun 22 15:25:05 +0000 2017
# 14  Thu Jun 22 15:27:10 +0000 2017
#
#                                                                                                                                              text  \
# 1                                                               Northwestern Mutual Life Insurance and Financial Services https://t.co/5BD852EmkV
# 2   Read Daily @NU_Alumni for summary of last 24 hours on Twitter for #Northwestern &amp; #B1GCats https://t.co/dikjyJ9WAs Stories via @SarahKuta
# 3                             When a visitor comes to the Medill campus and asks us if we are all from Northwestern...... https://t.co/xApl204yoj
# 8                                                            Ha! No. I wouldn't be seen with one of those. \nNorthwestern https://t.co/FFFl09zpEW
# 9                                                 Northwestern fan or not, The Play was one for the ages. Cast your vote! https://t.co/syFcumi2Qq
# 10                            RT @drewwalters23: Orlando city awards Gala, excited to help our city's youth #Northwestern https://t.co/3SX8woPI4d
# 11                               @hboulware @corrcomm The author is director of Northwestern's legal studies program. Oy. https://t.co/eCNUtFR5zJ
# 12              RT @DaGold3nChild: Extremely blessed to receive an offer from Northwestern State #Forkem #AGTG #RecruitLC https://t.co/nTJCP2FzmI
# 13                                                  College Coaches; @NKBaseball 17u plays in the @PastimeBaseball Northwestern TOC this weekend.
# 14                      Schedule;\nThurs- 1:30 and Northwestern\nFri- 3:45 and 6:00 at Trinity International University \nSat- 1:30 at Trout Park
#
#     retweet_count  favorite_count filter_level quoted_status_id_str  \
# 1               0               0          low                 None
# 2               0               0          low                 None
# 3               0               0          low                 None
# 8               0               0          low   877869817058828288
# 9               0               0          low   877861089496645633
# 10              0               0          low                 None
# 11              0               0          low                 None
# 12              0               0          low                 None
# 13              0               0          low                 None
# 14              0               0          low                 None
#
#                         created_at  default_profile_image  \
# 1   Sun Mar 10 14:23:19 +0000 2013                  False
# 2   Tue Feb 10 18:11:05 +0000 2009                  False
# 3   Tue May 31 04:08:57 +0000 2011                  False
# 8   Tue Sep 01 18:08:12 +0000 2009                  False
# 9   Sun Jun 03 15:05:39 +0000 2012                  False
# 10  Tue Dec 14 23:43:40 +0000 2010                  False
# 11  Mon Sep 28 06:27:55 +0000 2009                  False
# 12  Mon Aug 04 03:24:29 +0000 2014                  False
# 13  Sun Apr 06 15:32:53 +0000 2014                  False
# 14  Sun Apr 06 15:32:53 +0000 2014                  False
#
#                                                                                                                                                       description  \
# 1               Compensation consultant, teacher and student of human behavior: my philosophy is that convetional wisdon is always conventional but rarely wisdom
# 2                                                    Promoting #Northwestern University alumni & #B1GCats topics since 2009. Use my Lists to find other @NUAlumni
# 3                                                                             Dillard University Alum | Medill MSJ '17 | send sneakers (10/8): astasiawilli@gmail
# 8          Seahawks beat writer for The News Tribune. Former AP sports writer in Seattle, UW director of writing. West Point graduate. Steubenville, Ohio native.
# 9                                                                                        What I Love:  my family, my work, Northwestern Wildcats, clever wordplay
# 10                                                                                                      Hey! Take me strong! I'm here- http://tinyurl.com/me6tpm9
# 11   Long-ago journalist for the likes of  NYT and LAT and current author/co-author of nearly 20 books who thinks that sarcasm is the highest form of patriotism.
# 12                                                                                                    LCHS 18' |WR3| Isaiah 44:24|#Ekenation Click that link 👇🏾👇🏾
# 13  Grad Assistant/Recruiting Coordinator for Trinity International University Baseball and Head Coach for Northern Knights Baseball. Bemidji State Baseball alum
# 14  Grad Assistant/Recruiting Coordinator for Trinity International University Baseball and Head Coach for Northern Knights Baseball. Bemidji State Baseball alum
#
#     favourites_count  followers_count following  friends_count      id_str  \
# 1                  0               87      None            153  1257129522
# 2              17934             1373      None           2439    20531237
# 3              34189             2926      None           1765   308281620
# 8               2850            19029      None           1061    70744212
# 9                892               59      None            260   598482468
# 10               348                5      None              2   226744924
# 11              3190             2678      None            196    77943492
# 12              2711             1128      None            921  2705526270
# 13               767              242      None            625  2430625008
# 14               767              242      None            625  2430625008
#
#       screen_name  statuses_count          location  \
# 1      JimSillery             506  Eden Prairie, MN
# 2       NU_alumni           11382       Chicago, IL
# 3     AstasiaWill          115663          out here
# 8    gbellseattle           48534           Seattle
# 9     FrancieTurk              42              None
# 10    turecaboo12             464              None
# 11      joelengel           47583    Southern Calif
# 12  DaGold3nChild            5896       Houston, TX
# 13    CoachKatz23             782              None
# 14    CoachKatz23             783              None
#
#                      time_zone  verified
# 1                         None     False
# 2   Central Time (US & Canada)     False
# 3   Central Time (US & Canada)     False
# 8   Pacific Time (US & Canada)      True
# 9                         None     False
# 10                        None     False
# 11  Pacific Time (US & Canada)     False
# 12                        None     False
# 13                        None     False
# 14                        None     False

# %%
# preview uic data 
df[df['text'].str.contains(" UIC ", na=False)][:10]
# Out:
#                      tweet_created  \
# 35  Thu Jun 22 15:42:14 +0000 2017
#
#                                                                                                                                             text  \
# 35  Presale Alert!  Presale Update: A Perfect Circle Presale Tickets at UIC Pavilion in Chicago https://t.co/4Xud9q1T0P… https://t.co/4kIj37Di8P
#
#     retweet_count  favorite_count filter_level quoted_status_id_str  \
# 35              0               0          low                 None
#
#                         created_at  default_profile_image  \
# 35  Wed Nov 25 20:01:57 +0000 2009                  False
#
#                                                            description  \
# 35  We provide Free Presale Passwords for Concerts and Sporting Events
#
#     favourites_count  followers_count following  friends_count    id_str  \
# 35                 0              135      None            174  92599443
#
#      screen_name  statuses_count location                   time_zone  \
# 35  concertcodes           27932      USA  Eastern Time (US & Canada)
#
#     verified
# 35     False

# %%
# define bucket
my_bucket = 'msca-bdp-students-bucket/shared_data/kmr1'

# %%
# save sample
fltr2.write.format("com.databricks.spark.csv").\
option("header","true").\
mode('overwrite').\
save('gs://' + my_bucket + '/sample')

# %% [markdown]
# ### Reading/Filtering Full Data

# %%
# read in data. Note ~350 million records, taking 25 minutes to read in 
# %time data_read = spark.read.json('gs://msca-bdp-tweets/Tweets')
data_read.count()
# Out:
# CPU times: user 234 ms, sys: 69.6 ms, total: 304 ms
# Wall time: 25min 27s
# 348412387

# %%
# words for filtering 
words = ["uchicago", 
         "university of chicago", 
         "depaul", 
         "depaul university", 
         "depaulu",
         "northwestern",
         "northwesternu",
         "northwestern university",
         "university of illinois at chicago",
         "uic.edu", 
         " uic ",
         " uic's "
         ]

# %%
# filter keywords and relevant columns 
# %time data_filter = data_read.filter(psf.lower(data_read.text).rlike('|'.join(words))).\
select([col("created_at").alias("tweet_created"),\
        "text",\
        "lang",\
        "retweet_count",\
        "favorite_count",\
        "filter_level",\
        "user.statuses_count",\
        "quoted_status_id_str",\
        "user.created_at",\
        "user.default_profile_image",\
        "user.description",\
        "user.favourites_count",\
        "user.followers_count",\
        "user.following",\
        "user.friends_count",\
        "user.id_str",\
        "user.screen_name",\
        "user.location",\
        "user.time_zone",\
        "user.verified"])
# Out:
# CPU times: user 16.1 ms, sys: 5.18 ms, total: 21.2 ms
# Wall time: 312 ms

# %%
# define bucket
my_bucket = 'msca-bdp-students-bucket/shared_data/kmr1'

# %%
# save data 
data_filter.write.format("com.databricks.spark.csv").\
option("header","true").\
mode('overwrite').\
save('gs://' + my_bucket + '/data_filter3')

# %%
# preview 
data_filter.limit(5).toPandas()
# Out:
#                     tweet_created  \
# 0  Thu Jun 22 23:17:13 +0000 2017
# 1  Thu Jun 22 23:17:56 +0000 2017
# 2  Thu Jun 22 23:19:12 +0000 2017
# 3  Thu Jun 22 23:21:03 +0000 2017
# 4  Thu Jun 22 23:21:10 +0000 2017
#
#                                                 text lang  retweet_count  \
# 0  ...A SIGNIFICANT WEATHER ADVISORY HAS BEEN ISS...   en              0
# 1  @SheWhoVotes He went to Northwestern Law Schoo...   en              0
# 2  @DIRECTV will u like 2b mah girlfriend northwe...   en              0
# 3  'The Play' by Northwestern is nominated for Be...   en              0
# 4  Tornado Warning for..Northwestern Prairie Coun...   en              0
#
#    favorite_count filter_level quoted_status_id_str  \
# 0               0          low                 None
# 1               0          low                 None
# 2               0          low                 None
# 3               0          low                 None
# 4               0          low                 None
#
#                        created_at  default_profile_image  \
# 0  Thu Oct 18 05:51:36 +0000 2012                  False
# 1  Sat Feb 20 23:45:00 +0000 2016                  False
# 2  Wed Mar 22 01:46:38 +0000 2017                  False
# 3  Wed Sep 23 21:00:56 +0000 2009                  False
# 4  Wed Dec 11 17:46:29 +0000 2013                  False
#
#                                          description  favourites_count  \
# 0  AmericaAlerts provides alerts for weather, ear...                 0
# 1  Trust me I'm verified! - Voted 3rd Least influ...              1189
# 2                                               None                 3
# 3  'I have a high tolerance and an expense accoun...             12014
# 4  White County 9-1-1 Dispatch Center.  Searcy, A...                 5
#
#    followers_count following  friends_count              id_str  \
# 0              602      None            607           888181566
# 1               85      None            107  701190848751403008
# 2                8      None             66  844364663672492032
# 3              210      None            467            76755128
# 4              219      None             77          2241132438
#
#            location                   time_zone  verified
# 0    Sebastopol, CA                        None     False
# 1        Antarctica                        None     False
# 2              None  Eastern Time (US & Canada)     False
# 3           Chicago             America/Chicago     False
# 4  Searcy, Arkansas                        None     False

# %% [markdown]
# ### Create University-Specific Datasets

# %%
# read in data
# !gsutil ls 'gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3' | head -10
# Out:
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/_SUCCESS
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00000-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00001-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00002-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00003-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00004-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00005-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00006-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3/part-00007-3477c4a9-8263-4df9-b59a-d273b1b980ea-c000.csv
# Exception ignored in: <_io.TextIOWrapper name='<stdout>' mode='w' encoding='utf-8'>
# BrokenPipeError: [Errno 32] Broken pipe

# %%
# define bucket
my_bucket = 'msca-bdp-students-bucket/shared_data/kmr1/data_filter3'

# %%
# read in data
# %time data_filter = spark.read.csv('gs://msca-bdp-students-bucket/shared_data/kmr1/data_filter3', header='true', inferSchema='true', sep=',', quote='"')
data_filter.cache()

# %%
# note ~6 million records across all 4 universities 
data_filter.count()
# Out:
# 5988744

# %%
# preview data 
data_filter.limit(10).toPandas()
# Out:
#                               tweet_created  \
# 0            Wed Mar 14 20:15:02 +0000 2018
# 1            Wed Mar 14 20:15:02 +0000 2018
# 2            Wed Mar 14 20:15:02 +0000 2018
# 3            Wed Mar 14 20:15:02 +0000 2018
# 4  This is insane. https://t.co/tSd2E7Z4Fo"
# 5            Wed Mar 14 20:15:03 +0000 2018
# 6            Wed Mar 14 20:15:03 +0000 2018
# 7            Wed Mar 14 20:15:03 +0000 2018
# 8            Wed Mar 14 20:15:03 +0000 2018
# 9            Wed Mar 14 20:15:03 +0000 2018
#
#                                                 text  lang retweet_count  \
# 0  RT @kimbrolyclaire: @NorthwesternU It looks to...    en             0
# 1  there’s reports of a gunman at northwestern rn...    en             0
# 2  RT @KatieLittle: View of snipers from Maple/Em...    en             0
# 3  Anxiously waiting to hear from my northwestern...  None          None
# 4                                                 en     0             0
# 5  RT @Evan_Rosenfeld: BREAKING: Northwestern Uni...    en             0
# 6  RT @dianexlston: Also I feel like? We probably...    en             0
# 7  RT @dcopaken: This is my daughter. Right now. ...    en             0
# 8  RT @chicagotribune: Breaking: Police respond t...    en             0
# 9  RT @thehill: #BREAKING: Shots fired at Northwe...    en             0
#
#   favorite_count filter_level      statuses_count  \
# 0              0          low               74555
# 1              0          low                3647
# 2              0          low                 494
# 3           None         None                None
# 4            low         7041  974015378018856960
# 5              0          low                1357
# 6              0          low               28361
# 7              0          low               42703
# 8              0          low              121823
# 9              0          low               27365
#
#              quoted_status_id_str                      created_at  \
# 0                            None  Fri Mar 26 12:27:01 +0000 2010
# 1                            None  Tue Jun 06 23:18:14 +0000 2017
# 2                            None  Wed Jul 20 01:08:14 +0000 2016
# 3                            None                            None
# 4  Tue Apr 09 00:53:33 +0000 2013                           false
# 5              974011208687869955  Sun Jul 20 09:09:43 +0000 2008
# 6                            None  Sat Mar 12 11:09:25 +0000 2016
# 7                            None  Mon Sep 29 01:35:39 +0000 2008
# 8                            None  Sun Jul 26 02:29:22 +0000 2009
# 9                            None  Fri Nov 13 04:57:06 +0000 2015
#
#                                default_profile_image  \
# 0                                              false
# 1                                              false
# 2                                              false
# 3                                               None
# 4  Getting my doctorals @NorthwesternU | black ac...
# 5                                              false
# 6                                              false
# 7                                              false
# 8                                              false
# 9                                              false
#
#                                          description favourites_count  \
# 0                                               None           115991
# 1       i only yell in my tweets and rt guanlin pics             5097
# 2  Student @northwesternu | Evans Scholar🏌🏻| Poli...              236
# 3                                               None             None
# 4                                               3005              273
# 5  dem, filthy liberal, glock lover, pro-choice, ...              622
# 6                                               None            20958
# 7  Married to a former Roller Derby Rockstar. Als...             3758
# 8  ✨ Love ✨ Human Rights ✨ Animal Rights ✨ Fan Gi...            12998
# 9  I believe in the truth, the whole truth, and n...            39672
#
#   followers_count following friends_count              id_str  \
# 0             645      None          1547           126610908
# 1              71      None           182  872231183702274049
# 2              42      None           128  755569975855833088
# 3            None      None          None                None
# 4            None       251    1337981354       _thaWRIGHTway
# 5              73      None           178            15499922
# 6            3701      None          3741  708610844993658880
# 7             321      None          1440            16505796
# 8            2401      None          1423            60210356
# 9             129      None           114          4219854912
#
#        screen_name         location                   time_zone verified
# 0       kitty2city             None                        None    false
# 1     guanlinvibes              chi                        None    false
# 2      DylanGresik          Chicago                        None    false
# 3             None             None                        None     None
# 4      Chicago, IL             None                       false     None
# 5      TheGameGuru        Ohio, USA  Eastern Time (US & Canada)    false
# 6      muttslikeme            Eridu                        None    false
# 7  SaysMyDerbyWife             None  Eastern Time (US & Canada)    false
# 8  Phoenixs_Flame_      Chicagoland  Central Time (US & Canada)    false
# 9     TaniaMaglasu  Whitby, Ontario                        None    false

# %%
# filter out english tweets only 
# %time data_filter = data_filter.filter(col('lang')=='en')
# Out:
# CPU times: user 2.09 ms, sys: 571 µs, total: 2.66 ms
# Wall time: 82.5 ms

# %%
# this creates significant reduction in volume 
data_filter.count()
# Out:
# 3432368

# %%
# define column data structure 
data_filter = data_filter.withColumn("tweet_created",col("tweet_created").cast('string')).\
withColumn("text",col("text").cast('string')).\
withColumn("retweet_count",col("retweet_count").cast('integer')).\
withColumn("favorite_count",col("favorite_count").cast('integer')).\
withColumn("filter_level",col("filter_level").cast('string')).\
withColumn("quoted_status_id_str",col("quoted_status_id_str").cast('string')).\
withColumn("created_at",col("created_at").cast('string')).\
withColumn("default_profile_image",col("default_profile_image").cast('string')).\
withColumn("description",col("description").cast('string')).\
withColumn("favourites_count",col("favourites_count").cast('integer')).\
withColumn("followers_count",col("followers_count").cast('integer')).\
withColumn("following",col("following").cast('string')).\
withColumn("friends_count",col("friends_count").cast('integer')).\
withColumn("id_str",col("id_str").cast('string')).\
withColumn("location",col("location").cast('string')).\
withColumn("time_zone",col("time_zone").cast('string')).\
withColumn("verified",col("verified").cast('string'))

# %%
# define bucket
my_bucket = 'msca-bdp-students-bucket/shared_data/kmr1'

# %%
# filter out uchicago data 
uchi_words = ["uchicago", 
         "university of chicago"
         ]

# %time uchicago = data_filter.filter(psf.lower(data_filter.text).rlike('|'.join(uchi_words)))
# Out:
# CPU times: user 4.11 ms, sys: 0 ns, total: 4.11 ms
# Wall time: 22.5 ms

# %%
# number of records 
uchicago.count()
# Out:
# 572868

# %%
# save as pandas df 
# %time uchicago_df = uchicago.toPandas()
# Out:
# CPU times: user 5.91 s, sys: 744 ms, total: 6.65 s
# Wall time: 13 s

# %%
# save as csv file
uchicago_df.to_csv('gs://' + my_bucket + '/uchicago_df')

# %%
# filter out uchicago words 
depaul_words = [
         "depaul", 
         "depaul university", 
         "depaulu"
         ]

# %time depaul = data_filter.filter(psf.lower(data_filter.text).rlike('|'.join(depaul_words)))

# results in 504,813 records 
depaul.count()
# Out:
# CPU times: user 2.56 ms, sys: 176 µs, total: 2.73 ms
# Wall time: 65 ms
# 504813

# %%
# save as csv 
# %time depaul_df = depaul.toPandas()
depaul_df.to_csv('gs://' + my_bucket + '/depaul_df')
# Out:
# CPU times: user 6.92 s, sys: 235 ms, total: 7.15 s
# Wall time: 11.7 s

# %%
# filter out northwestern data
northwestern_words = [
         "northwestern",
         "northwesternu",
         "northwestern university",
         ]

# %time northwestern = data_filter.filter(psf.lower(data_filter.text).rlike('|'.join(northwestern_words)))

# results in 2.1 million tweets, which are significant reduced in later analysis 
northwestern.count()
# Out:
# CPU times: user 2.65 ms, sys: 0 ns, total: 2.65 ms
# Wall time: 27 ms
# 2122479

# %%
# save as csv 
# %time northwestern_df = northwestern.toPandas()
northwestern_df.to_csv('gs://' + my_bucket + '/northwestern_df')
# Out:
# CPU times: user 22.9 s, sys: 1.81 s, total: 24.7 s
# Wall time: 39.3 s

# %%
# filter out uic data 
uic_words = ["university of illinois at chicago",
             "uic.edu", 
             " uic ",
             " uic's "
            ]

# %time uic = data_filter.filter(psf.lower(data_filter.text).rlike('|'.join(uic_words)))

# results in 182,460 records 
uic.count()
# Out:
# CPU times: user 2.58 ms, sys: 0 ns, total: 2.58 ms
# Wall time: 62.5 ms
# 182460

# %%
# save as pandas dataframe
# %time uic_df = uic.toPandas()
uic_df.to_csv('gs://' + my_bucket + '/uic_df')
# Out:
# CPU times: user 1.9 s, sys: 56.5 ms, total: 1.96 s
# Wall time: 6.9 s

# %%
# unpersist data file 
data_filter.unpersist()
# Out:
# DataFrame[tweet_created: string, text: string, lang: string, retweet_count: int, favorite_count: int, filter_level: string, statuses_count: string, quoted_status_id_str: string, created_at: string, default_profile_image: string, description: string, favourites_count: int, followers_count: int, following: string, friends_count: int, id_str: string, screen_name: string, location: string, time_zone: string, verified: string]
